# %% [markdown]
# ## Fixations numerations fix (for aDDM_toolbox)

# %% [markdown]
# + Change the numeration of trials once they are separated in Like and Dislike conditions (avoid breaks in trial number)
# + Calculate the gaze time for each trial

# %%
import numpy as np
import pandas as pd
from pandas.core.frame import DataFrame as DF
import seaborn as sns
sns.set(color_codes=True)
#np.random.seed(sum(map(ord, "distributions")))
from sklearn import linear_model  # packages for the logistic regression function to plot the logistic regression 
from sklearn.linear_model import LogisticRegression # packages for the logistic regression function to plot the logistic regression 
import scipy
from scipy import stats, integrate
from scipy.stats import mode
from scipy.stats.stats import pearsonr # Pearson's correlation
from copy import copy as copy
import operator as operator
import pylab

# %% [markdown]
# # Like condition data

# %%
#Input has the fixation and expdat with breaks in trial numerations (due to separation in Like and Dislike conditions)
#data_fix = pd.read_csv('/Users/pradyumna/Documents/gitDocs/FF2018/Output/fixations_collapsed_FFA_Dislike_v1.csv') 
#data_expData = pd.read_csv('/Users/pradyumna/Documents/gitDocs/FF2018/Output/expdata_bin_FFA_Dislike_v1.csv') 

#for binned data
# we use v1 that is the version that doesn't have the numeration corrected
#data_fix = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/InputData/fixations_collapsed_FFA_Like_31.csv') 
#data_expData = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/output/expdata_bin_FFA_Like_31.csv') 

#for not binned data
data_fix = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/Output/fixations_collapsed_PF2019_More_33.csv') 
data_expData = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/Output/expdata_PF2019_More_33.csv') 

data_expData = data_expData.apply(pd.to_numeric, errors='ignore')
data_fix = data_fix.apply(pd.to_numeric, errors='ignore')

# %%
print(data_fix.parcode.unique())
print(data_expData.parcode.unique())
# Out:
# [ 1  2  3  4  5  8  9 10 11 12 13 14 15 16 18 19 20 21 22 23 24 26 27 28
#  29 31 32 34 35 36 39]
# [ 1  2  3  4  5  8  9 10 11 12 13 14 15 16 18 19 20 21 22 23 24 26 27 28
#  29 31 32 34 35 36 39]

# %% [markdown]
# ## Replace trial numerations

# %%
partNums = pd.unique(data_fix["parcode"])

new_fix_dataframe = data_fix.iloc[0:0]
new_expData_dataframe = data_expData.iloc[0:0]

for i in partNums:
    old_index_trial = []
    new_index_trial = []
    participant_trials = []
    
    participant_trials = data_expData.loc[data_expData['parcode'] == i]
    part_fix_trials = data_fix.loc[data_fix['parcode'] == i]
    
    old_index_trial = participant_trials['trial'].values
    new_index_trial = range(len(old_index_trial))
    
    for j in new_index_trial:
            #insert new column with new trial numeration : case trialData
            trialCol2Replace = participant_trials['trial'].replace(old_index_trial[j], new_index_trial[j])
            participant_trials = participant_trials.drop(['trial'], axis=1)
            participant_trials.insert(1,'trial',trialCol2Replace)
            
            #insert new column with new trial numeration : case Fixations
            fixCol2Replace = part_fix_trials['trial'].replace(old_index_trial[j], new_index_trial[j]).values
            part_fix_trials = part_fix_trials.drop(['trial'], axis=1)
            part_fix_trials.insert(1,'trial',fixCol2Replace)
            
            #print (participant_trials)
            time_trials = part_fix_trials['fix_time'].values
            
            ix = np.in1d(time_trials, 0)
            delete_fix_idx = np.where(ix)
            part_fix_trials = part_fix_trials.drop(part_fix_trials.index[delete_fix_idx])
            
    new_fix_dataframe = pd.concat([new_fix_dataframe, part_fix_trials],axis = 0)
    new_expData_dataframe = pd.concat([new_expData_dataframe, participant_trials], axis = 0)

# %%
new_fix_dataframe
# Out:
#        parcode  trial  fix_item  fix_time
# 0            1      0         3       313
# 1            1      0         1       552
# 2            1      0         2       732
# 3            1      0         1       412
# 4            1      1         3       249
# 5            1      1         1       576
# 6            1      1         2       742
# 7            1      1         1      1804
# 8            1      2         3       290
# 9            1      2         1       630
# 10           1      2         2       780
# 11           1      3         3       264
# 12           1      3         1       630
# 13           1      3         2      1086
# 14           1      3         1      1178
# 15           1      3         2      1058
# 16           1      3         1      2026
# 17           1      3         2      1224
# 18           1      4         3       258
# 19           1      4         1       864
# 20           1      4         2       767
# 21           1      5         3       230
# 22           1      5         0       124
# 23           1      5         1       694
# 24           1      5         2      1179
# 25           1      6         3       230
# 26           1      6         1       682
# 27           1      6         2      2086
# 28           1      6         1      1261
# 29           1      7         3       231
# ...        ...    ...       ...       ...
# 16187       39    111         3       438
# 16188       39    111         1       606
# 16189       39    111         2      1386
# 16190       39    111         1       490
# 16192       39    112         1       610
# 16193       39    112         2      2336
# 16194       39    112         1       833
# 16196       39    113         2       851
# 16197       39    113         1       856
# 16198       39    113         2       245
# 16200       39    114         1       888
# 16201       39    114         2       810
# 16202       39    114         1       435
# 16204       39    115         1       659
# 16205       39    115         2       736
# 16206       39    116         3        18
# 16207       39    116         1       704
# 16208       39    116         2       491
# 16210       39    117         2       189
# 16211       39    117         1      1192
# 16212       39    117         2      1420
# 16213       39    117         0       112
# 16214       39    117         1       481
# 16215       39    118         3       194
# 16216       39    118         1      1078
# 16217       39    118         2      2800
# 16218       39    118         1       868
# 16219       39    118         2       340
# 16221       39    119         2       986
# 16222       39    119         1       919
#
# [14215 rows x 4 columns]

# %%
new_expData_dataframe
# Out:
#       parcode  trial    rt  choice  item_left  item_right
# 0           1      0  2009      -1        0.0         0.0
# 1           1      1  3371      -1        5.0         4.0
# 2           1      2  1700       1        0.0         5.0
# 3           1      3  7466       1        1.0         2.0
# 4           1      4  1889       1        5.0         5.0
# 5           1      5  2227       1        4.0         4.0
# 6           1      6  4259      -1        4.0         0.0
# 7           1      7  3505      -1        3.0         0.0
# 8           1      8  2548      -1        3.0         0.0
# 9           1      9  3226       1        0.0         5.0
# 10          1     10  4604      -1        4.0         0.0
# 11          1     11  6333      -1        0.0         5.0
# 12          1     12  5716      -1        0.0         0.0
# 13          1     13  3562      -1        5.0         0.0
# 14          1     14  2447      -1        4.0         0.0
# 15          1     15  2120       1        1.0         4.0
# 16          1     16  6932       1        5.0         5.0
# 17          1     17  4274       1        1.0         4.0
# 18          1     18  6854      -1        4.0         2.0
# 19          1     19  6698      -1        0.0         0.0
# 20          1     20  2913      -1        0.0         0.0
# 21          1     21  4513      -1        4.0         3.0
# 22          1     22  2110       1        4.0         5.0
# 23          1     23  3385      -1        4.0         2.0
# 24          1     24  2456       1        2.0         5.0
# 25          1     25  2136      -1        4.0         4.0
# 26          1     26  7010       1        0.0         3.0
# 27          1     27  4784      -1        0.0         0.0
# 28          1     28  2697       1        0.0         3.0
# 29          1     29  4654       1        1.0         3.0
# ...       ...    ...   ...     ...        ...         ...
# 3690       39     90  2713      -1        3.0         4.0
# 3691       39     91  2609       1        2.0         4.0
# 3692       39     92  2694      -1        3.0         3.0
# 3693       39     93  2761       1        2.0         3.0
# 3694       39     94  2285       1        3.0         1.0
# 3695       39     95  1613      -1        2.0         1.0
# 3696       39     96  2841       1        1.0         2.0
# 3697       39     97  2258      -1        1.0         3.0
# 3698       39     98  1243       1        1.0         4.0
# 3699       39     99  1767      -1        3.0         1.0
# 3700       39    100  2423       1        4.0         2.0
# 3701       39    101  1217      -1        3.0         3.0
# 3702       39    102  3420       1        4.0         3.0
# 3703       39    103  8198      -1        1.0         4.0
# 3704       39    104  5417       1        3.0         4.0
# 3705       39    105  1100       1        1.0         2.0
# 3706       39    106  1789      -1        4.0         1.0
# 3707       39    107  4438       1        3.0         3.0
# 3708       39    108  3252       1        3.0         3.0
# 3709       39    109  4139      -1        4.0         1.0
# 3710       39    110  2098      -1        1.0         2.0
# 3711       39    111  2920      -1        4.0         3.0
# 3712       39    112  3779      -1        2.0         2.0
# 3713       39    113  1952       1        1.0         3.0
# 3714       39    114  2133      -1        1.0         1.0
# 3715       39    115  1395       1        2.0         4.0
# 3716       39    116  1213       1        1.0         3.0
# 3717       39    117  3394      -1        1.0         1.0
# 3718       39    118  5280       1        3.0         3.0
# 3719       39    119  1905      -1        2.0         3.0
#
# [3720 rows x 6 columns]

# %%
new_expData_dataframe.to_csv("Output/aDDM_Data_FF2018_Like_YesBin_31.csv",index = True)
new_fix_dataframe.to_csv("Output/aDDM_Fix_FF2018_Like_YesBin_31.csv",index = True)

# %% [markdown]
# # Dislike Condition Data

# %%
#Input has the fixation and expdat with breaks in trial numerations (due to separation in Like and Dislike conditions)
#data_fix = pd.read_csv('/Users/pradyumna/Documents/gitDocs/FF2018/Output/fixations_collapsed_FFA_Dislike_v1.csv') 
#data_expData = pd.read_csv('/Users/pradyumna/Documents/gitDocs/FF2018/Output/expdata_bin_FFA_Dislike_v1.csv') 

#for binned data
# we use v1 that is the version that doesn't have the numeration corrected
#data_fix = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/InputData/fixations_collapsed_FFA_Like_31.csv') 
#data_expData = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/output/expdata_bin_FFA_Like_31.csv') 

#for not binned data
data_fix = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/Output/fixations_collapsed_FFA_Dislike_31.csv') 
data_expData = pd.read_csv('/Users/pradyumna/Documents/GiTs/FF2018/Output/expdata_bin_FFA_Dislike_31.csv') 

data_expData = data_expData.apply(pd.to_numeric, errors='ignore')
data_fix = data_fix.apply(pd.to_numeric, errors='ignore')

# %% [markdown]
# ## Replace numerations

# %%
partNums = pd.unique(data_fix["parcode"])

new_fix_dataframe = data_fix.iloc[0:0]
new_expData_dataframe = data_expData.iloc[0:0]

for i in partNums:
    old_index_trial = []
    new_index_trial = []
    participant_trials = []
    
    participant_trials = data_expData.loc[data_expData['parcode'] == i]
    part_fix_trials = data_fix.loc[data_fix['parcode'] == i]
    
    old_index_trial = participant_trials['trial'].values
    new_index_trial = range(len(old_index_trial))
    
    for j in new_index_trial:
            #insert new column with new trial numeration : case trialData
            trialCol2Replace = participant_trials['trial'].replace(old_index_trial[j], new_index_trial[j])
            participant_trials = participant_trials.drop(['trial'], axis=1)
            participant_trials.insert(1,'trial',trialCol2Replace)
            
            #insert new column with new trial numeration : case Fixations
            fixCol2Replace = part_fix_trials['trial'].replace(old_index_trial[j], new_index_trial[j]).values
            part_fix_trials = part_fix_trials.drop(['trial'], axis=1)
            part_fix_trials.insert(1,'trial',fixCol2Replace)
            
            #print (participant_trials)
            time_trials = part_fix_trials['fix_time'].values
            
            ix = np.in1d(time_trials, 0)
            delete_fix_idx = np.where(ix)
            part_fix_trials = part_fix_trials.drop(part_fix_trials.index[delete_fix_idx])
            
    new_fix_dataframe = pd.concat([new_fix_dataframe, part_fix_trials],axis = 0)
    new_expData_dataframe = pd.concat([new_expData_dataframe, participant_trials], axis = 0)

# %%
new_expData_dataframe.to_csv("Output/aDDM_Data_FF2018_Dislike_YesBin_31.csv",index = True)
new_fix_dataframe.to_csv("Output/aDDM_Fix_FF2018_Dislike_YesBin_31.csv",index = True)

# %% [markdown]
# ## Flip values

# %%
item_left_inv = 5 - new_expData_dataframe["item_left"] 
item_right_inv = 5 - new_expData_dataframe["item_right"]

# %%
new_expData_dataframe.drop(columns=['item_left', 'item_right'])
new_expData_dataframe['item_left'] = item_left_inv
new_expData_dataframe['item_right'] = item_right_inv

# %%
new_expData_dataframe.to_csv("Output/aDDM_Data_FF2018_Dislike_YesBin_31_Inv.csv",index = True)
