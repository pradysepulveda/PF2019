# %%
import numpy as np
import pandas as pd
from pandas.core.frame import DataFrame as DF
import seaborn as sns
sns.set(color_codes=True)
#np.random.seed(sum(map(ord, "distributions")))
from sklearn import linear_model  # packages for the logistic regression function to plot the logistic regression 
from sklearn.linear_model import LogisticRegression # packages for the logistic regression function to plot the logistic regression 
import scipy
from scipy import stats, integrate
from scipy.stats import mode
from scipy.stats.stats import pearsonr # Pearson's correlation
from copy import copy as copy
import operator as operator
import pylab

# Plotting tools
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %pylab inline
figsize(5, 5)

import glob
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['copy', 'pylab']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
PathTrialReport ="/Users/pradyumna/OneDrive - University College London/PhD Projects/PerceptualFraming/Data/Pilots/P3/RESULTS_FILE.txt"

TrialRepFrame = [pd.read_csv(PathTrialReport, sep="\t")]
TrialDataFrame = pd.concat(TrialRepFrame)
#TrialDataFrame

# %%
TrialDataFrame
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 0              P3             1         50          60               m
# 1              P3             2         40          50               m
# 2              P3             3         50          41               z
# 3              P3             4         59          50               m
# 4              P3             5         50          40               m
# 5              P3             6         61          50               m
# 6              P3             7         50          62               m
# 7              P3             8         38          50               m
# 8              P3             9         50          61               m
# 9              P3            10         61          50               m
# 10             P3            11         50          38               z
# 11             P3            12         62          50               z
# ...

# %%
ExpTrails =  TrialDataFrame.loc[(TrialDataFrame['trial_type'] == 'Experiment')]

# %%
ExpTrails
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 50             P3            51         80          98               m
# 51             P3            52         29          45               m
# 52             P3            53         51          45               z
# 53             P3            54         45          59               m
# 54             P3            55        115         125               m
# 55             P3            56         97         115               m
# 56             P3            57        100          80               z
# 57             P3            58        113         115               z
# 58             P3            59        105         115               m
# 59             P3            60        119         115               m
# 60             P3            61         80          72               z
# 61             P3            62         61          45               z
# ...

# %%
ExpTrails_1 =  ExpTrails.loc[(ExpTrails['moreorless'] == 'LESS')]

# %%
ExpTrails_1
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 90             P3            91        121         115               m
# 91             P3            92         39          45               z
# 92             P3            93         80          78               m
# 93             P3            94         60          80               z
# 94             P3            95         45          53               z
# 95             P3            96        115         127               z
# 96             P3            97         92          80               m
# 97             P3            98         72          80               z
# 98             P3            99         80         100               z
# 99             P3           100        100          80               m
# 100            P3           101         25          45               m
# 101            P3           102        115         111               m
# ...

# %%
ExpTrails_1
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 90             P3            91        121         115               m
# 91             P3            92         39          45               z
# 92             P3            93         80          78               m
# 93             P3            94         60          80               z
# 94             P3            95         45          53               z
# 95             P3            96        115         127               z
# 96             P3            97         92          80               m
# 97             P3            98         72          80               z
# 98             P3            99         80         100               z
# 99             P3           100        100          80               m
# 100            P3           101         25          45               m
# 101            P3           102        115         111               m
# ...

# %%
ExpTrails.loc[(ExpTrails['pairidlr'] == 1)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 83             P3            84         47          45               m
# 169            P3           170         45          47               m
# 176            P3           177         47          45               z
# 208            P3           209         45          47               z
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 83     2269.81    74   896.44       MORE  Experiment    ...            2
# 169   12807.30    14  1137.25   NEXTLESS  Experiment    ...            2
# 176    8536.63    54  4168.65       LESS  Experiment    ...            2
# 208   12474.89    44  2042.63       LESS  Experiment    ...            2
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest   lorr  pairidlr  \
# 83          45            False    45       MOST    No  Right         1
# 169         47            False    45       MOST   Yes   Left         1
# ...

# %%
ExpTrails.loc[(ExpTrails['DOTS_LEFT'] == 115) & (ExpTrails['DOTS_RIGHT'] == 101)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 110            P3           111        115         101               m
# 249            P3           250        115         101               z
# 289            P3           290        115         101               m
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 110   10673.52    24  2182.80       LESS  Experiment    ...          -14
# 249    4682.51    74  1610.83   NEXTLESS  Experiment    ...          -14
# 289    7874.51    34  1754.95       LESS  Experiment    ...          -14
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest  lorr  pairidlr  \
# 110        101            False   115     FEWEST    No  Left        57
# 249        115            False   115       MOST   Yes  Left        57
# 289        101            False   115     FEWEST    No  Left        57
#
#      PairIDFM  pairidmf
# 110        57        97
# 249        57        97
# ...

# %%
ExpTrails.loc[(ExpTrails['DOTS_LEFT'] == 101) & (ExpTrails['DOTS_RIGHT'] == 115)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 215            P3           216        101         115               m
# 255            P3           256        101         115               z
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 215   26791.23    14  1499.15       MORE  Experiment    ...          -14
# 255    2507.25    54  1132.79       LESS  Experiment    ...          -14
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest   lorr  pairidlr  \
# 215        115            False   115       MOST    No  Right        57
# 255        101            False   115     FEWEST    No  Right        57
#
#      PairIDFM  pairidmf
# 215        57       117
# 255        57       117
#
# [2 rows x 38 columns]

# %%
ExpTrails.loc[(ExpTrails['pairidlr'] == 57)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 110            P3           111        115         101               m
# 215            P3           216        101         115               m
# 249            P3           250        115         101               z
# 255            P3           256        101         115               z
# 289            P3           290        115         101               m
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 110   10673.52    24  2182.80       LESS  Experiment    ...          -14
# 215   26791.23    14  1499.15       MORE  Experiment    ...          -14
# 249    4682.51    74  1610.83   NEXTLESS  Experiment    ...          -14
# 255    2507.25    54  1132.79       LESS  Experiment    ...          -14
# 289    7874.51    34  1754.95       LESS  Experiment    ...          -14
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest   lorr  pairidlr  \
# ...

# %%
TrialDataFrame.loc[(TrialDataFrame['DOTS_LEFT'] == 70) & (TrialDataFrame['DOTS_RIGHT'] == 80)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 153            P3           154         70          80               m
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 153    4021.28    54   710.36       MORE  Experiment    ...          -10
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest   lorr  pairidlr  \
# 153         80            False    80       MOST    No  Right        35
#
#      PairIDFM  pairidmf
# 153        35        75
#
# [1 rows x 38 columns]

# %%
TrialDataFrame.loc[(TrialDataFrame['DOTS_LEFT'] == 80) & (TrialDataFrame['DOTS_RIGHT'] == 70)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 86             P3            87         80          70               z
# 112            P3           113         80          70               m
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 86     6039.16    34  1371.14       MORE  Experiment    ...          -10
# 112    5290.45    44   858.95       LESS  Experiment    ...          -10
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest  lorr  pairidlr  \
# 86          80            False    80       MOST    No  Left        35
# 112         70            False    80     FEWEST    No  Left        35
#
#      PairIDFM  pairidmf
# 86         35        55
# 112        35        55
#
# [2 rows x 38 columns]

# %%
TrialDataFrame.loc[(TrialDataFrame['DOTS_LEFT'] == 75) & (TrialDataFrame['DOTS_RIGHT'] == 80)]
# Out:
# Empty DataFrame
# Columns: [Session_Name_, Trial_Index_, DOTS_LEFT, DOTS_RIGHT, CHOICE_KEYPRESS, CHOICE_RT, CONF, CONF_RT, moreorless, trial_type, Slider_X, Unchosen_Nr, Correct_Count, Error_Count, Dot_Diff, CONF_MARKER_X, PICKED_LEFT, LEFT_MOST_DOTS, CONF_MARKER_Y, TRIAL_POINTS, TOTAL_POINTS, CORRECT, subblock, Cycle_N, DUMMY, Dot_Gen_List, BLOCK, Participant_Mean, variance, Chosen_Nr, Trial_Recycled_, base, BlockType, rest, lorr, pairidlr, PairIDFM, pairidmf]
# Index: []
#
# [0 rows x 38 columns]

# %%
TrialDataFrame.loc[(TrialDataFrame['DOTS_LEFT'] == 115) & (TrialDataFrame['DOTS_RIGHT'] == 101)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 110            P3           111        115         101               m
# 249            P3           250        115         101               z
# 289            P3           290        115         101               m
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 110   10673.52    24  2182.80       LESS  Experiment    ...          -14
# 249    4682.51    74  1610.83   NEXTLESS  Experiment    ...          -14
# 289    7874.51    34  1754.95       LESS  Experiment    ...          -14
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest  lorr  pairidlr  \
# 110        101            False   115     FEWEST    No  Left        57
# 249        115            False   115       MOST   Yes  Left        57
# 289        101            False   115     FEWEST    No  Left        57
#
#      PairIDFM  pairidmf
# 110        57        97
# 249        57        97
# ...

# %%
TrialDataFrame.loc[(TrialDataFrame['DOTS_LEFT'] == 101) & (TrialDataFrame['DOTS_RIGHT'] == 115)]
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 215            P3           216        101         115               m
# 255            P3           256        101         115               z
#
#      CHOICE_RT  CONF  CONF_RT moreorless  trial_type    ...     variance  \
# 215   26791.23    14  1499.15       MORE  Experiment    ...          -14
# 255    2507.25    54  1132.79       LESS  Experiment    ...          -14
#
#      Chosen_Nr  Trial_Recycled_  base  BlockType  rest   lorr  pairidlr  \
# 215        115            False   115       MOST    No  Right        57
# 255        101            False   115     FEWEST    No  Right        57
#
#      PairIDFM  pairidmf
# 215        57       117
# 255        57       117
#
# [2 rows x 38 columns]

# %%
TrialDataFrame.loc[TrialDataFrame['moreorless'] == 'MORE']
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 90             P1            91         45          40               z
# 91             P1            92        115         135               m
# 92             P1            93         25          45               z
# 93             P1            94        115         130               z
# 94             P1            95         90          80               m
# 95             P1            96         30          45               z
# 96             P1            97        135         115               m
# 97             P1            98         55          45               m
# 98             P1            99        100          80               m
# 99             P1           100         95         115               z
# 100            P1           101         45          25               m
# 101            P1           102        115         105               m
# ...

# %%
TrialDataFrame.data

# %%
TrialDataFrame
# Out:
#     Session_Name_  Trial_Index_  DOTS_LEFT  DOTS_RIGHT CHOICE_KEYPRESS  \
# 0              P1             1         60          50               m
# 1              P1             2         50          39               m
# 2              P1             3         62          50               m
# 3              P1             4         50          63               m
# 4              P1             5         50          37               z
# 5              P1             6         50          38               z
# 6              P1             7         50          38               z
# 7              P1             8         50          61               m
# 8              P1             9         50          39               z
# 9              P1            10         50          60               m
# 10             P1            11         40          50               m
# 11             P1            12         50          41               z
# ...
